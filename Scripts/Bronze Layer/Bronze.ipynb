# %% [markdown]
# # Meta Data for raw files

# %%
INGESTION_CONFIG = [
    {
        "source": "crm",
        "path": "/Volumes/e-commerce-databricks-project/landing_stage/raw_data/source_crm/cust_info.csv",
        "table": "`e-commerce-databricks-project`.bronze_layer.crm_cust_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/e-commerce-databricks-project/landing_stage/raw_data/source_crm/prd_info.csv",
        "table": "`e-commerce-databricks-project`.bronze_layer.crm_prd_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/e-commerce-databricks-project/landing_stage/raw_data/source_crm/sales_details.csv",
        "table": "`e-commerce-databricks-project`.bronze_layer.crm_sales_details"
    },
    {
        "source": "erp",
        "path": "/Volumes/e-commerce-databricks-project/landing_stage/raw_data/source_erp/CUST_AZ12.csv",
        "table": "`e-commerce-databricks-project`.bronze_layer.erp_cust_az12"
    },
    {
        "source": "erp",
        "path": "/Volumes/e-commerce-databricks-project/landing_stage/raw_data/source_erp/LOC_A101.csv",
        "table": "`e-commerce-databricks-project`.bronze_layer.erp_loc_a101"
    },
    {
        "source": "erp",
        "path": "/Volumes/e-commerce-databricks-project/landing_stage/raw_data/source_erp/PX_CAT_G1V2.csv",
        "table": "`e-commerce-databricks-project`.bronze_layer.erp_px_cat_g1v2"
    }
]

# %% [markdown]
# # Ingest Files into Bronze Tables

# %% [markdown]
# ## from CSV files to Delta Tables

# %%
for item in INGESTION_CONFIG:
    df = spark.read.csv(
        item["path"], 
        header=True,
        inferSchema=True,
        sep=',')
    df.write.format("delta").mode("overwrite").saveAsTable(item["table"])
