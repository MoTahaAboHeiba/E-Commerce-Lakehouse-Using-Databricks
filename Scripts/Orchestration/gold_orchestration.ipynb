# %%
from datetime import datetime

BASE = "/Workspace/Users/mohamed-aboheiba@outlook.com/E-Commerce-Databricks-Project/Scripts/Gold Layer"

notebooks = [
    f"{BASE}/Gold_Dim_products",
    f"{BASE}/Gold_Dim_customers",
    f"{BASE}/Gold_Fact_Sales",
]

for path in notebooks:
    start = datetime.now()
    print(f"[{start.strftime('%H:%M:%S')}] Starting: {path}")

    try:
        dbutils.notebook.run(path, timeout_seconds=1800)
        elapsed = round((datetime.now() - start).total_seconds(), 1)
        print(f"[{datetime.now().strftime('%H:%M:%S')}] Done: {path} ({elapsed}s)\n")

    except Exception as e:
        elapsed = round((datetime.now() - start).total_seconds(), 1)
        print(f"[{datetime.now().strftime('%H:%M:%S')}] FAILED: {path} ({elapsed}s)")
        print(f"Error: {str(e)}")
        raise

print("Gold layer complete.")
# Out:
# [18:26:21] Starting: /Workspace/Users/mohamed-aboheiba@outlook.com/E-Commerce-Databricks-Project/Scripts/Gold Layer/Gold_Dim_products
# [18:26:52] Done: /Workspace/Users/mohamed-aboheiba@outlook.com/E-Commerce-Databricks-Project/Scripts/Gold Layer/Gold_Dim_products (31.2s)
#
# [18:26:52] Starting: /Workspace/Users/mohamed-aboheiba@outlook.com/E-Commerce-Databricks-Project/Scripts/Gold Layer/Gold_Dim_customers
# [18:27:13] Done: /Workspace/Users/mohamed-aboheiba@outlook.com/E-Commerce-Databricks-Project/Scripts/Gold Layer/Gold_Dim_customers (20.9s)
#
# [18:27:13] Starting: /Workspace/Users/mohamed-aboheiba@outlook.com/E-Commerce-Databricks-Project/Scripts/Gold Layer/Gold_Fact_Sales
# [18:32:05] Done: /Workspace/Users/mohamed-aboheiba@outlook.com/E-Commerce-Databricks-Project/Scripts/Gold Layer/Gold_Fact_Sales (292.1s)
#
# Gold layer complete.
